# %% [markdown]
# <a href="https://colab.research.google.com/github/harshaelon/AI_Agents/blob/main/Simple_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install matplotlib

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #Reading the data from the csv files using read.csv

# %%
df=pd.read_csv("/content/weight-height.csv")

# %%
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
##scatter plots, to check the relation between features

# %%
plt.scatter(df['Weight'],df['Height'])

plt.xlabel("Height")
plt.ylabel("Weight")
plt.title("Weight vs Height")
plt.show()

# %%
#to find out whether this is positive relation or not, we can use corelation

# %%
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
columns=[df['Weight'],df['Height']]

# %%
## seaborn for visualization


import seaborn as sns
sns.pairplot(df)

# %%
df.drop('Gender',axis=1)
# Out:
#          Height      Weight
# 0     73.847017  241.893563
# 1     68.781904  162.310473
# 2     74.110105  212.740856
# 3     71.730978  220.042470
# 4     69.881796  206.349801
# ...         ...         ...
# 9995  66.172652  136.777454
# 9996  67.067155  170.867906
# 9997  63.867992  128.475319
# 9998  69.034243  163.852461
# 9999  61.944246  113.649103
#
# [10000 rows x 2 columns]

# %%
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
df1=df.drop('Gender',axis=1)

# %%
df1
# Out:
#          Height      Weight
# 0     73.847017  241.893563
# 1     68.781904  162.310473
# 2     74.110105  212.740856
# 3     71.730978  220.042470
# 4     69.881796  206.349801
# ...         ...         ...
# 9995  66.172652  136.777454
# 9996  67.067155  170.867906
# 9997  63.867992  128.475319
# 9998  69.034243  163.852461
# 9999  61.944246  113.649103
#
# [10000 rows x 2 columns]

# %%
df1.corr()
# Out:
#           Height    Weight
# Height  1.000000  0.924756
# Weight  0.924756  1.000000

# %%
sns.pairplot(df1)

# %%
df2=df.rename(columns={'Weight':'Height','Height':'Weight'})

# %%
df2
# Out:
#       Gender     Weight      Height
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
df2.drop('Gender',axis=1)
# Out:
#          Weight      Height
# 0     73.847017  241.893563
# 1     68.781904  162.310473
# 2     74.110105  212.740856
# 3     71.730978  220.042470
# 4     69.881796  206.349801
# ...         ...         ...
# 9995  66.172652  136.777454
# 9996  67.067155  170.867906
# 9997  63.867992  128.475319
# 9998  69.034243  163.852461
# 9999  61.944246  113.649103
#
# [10000 rows x 2 columns]

# %%
df2=df2.drop('Gender',axis=1)

# %%
df2
# Out:
#          Weight      Height
# 0     73.847017  241.893563
# 1     68.781904  162.310473
# 2     74.110105  212.740856
# 3     71.730978  220.042470
# 4     69.881796  206.349801
# ...         ...         ...
# 9995  66.172652  136.777454
# 9996  67.067155  170.867906
# 9997  63.867992  128.475319
# 9998  69.034243  163.852461
# 9999  61.944246  113.649103
#
# [10000 rows x 2 columns]

# %%
df2.corr()
# Out:
#           Weight    Height
# Weight  1.000000  0.924756
# Height  0.924756  1.000000

# %%
sns.pairplot(df2)

# %%
# to differentiate dependent and independent features

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
df2.head()
# Out:
#       Weight      Height
# 0  73.847017  241.893563
# 1  68.781904  162.310473
# 2  74.110105  212.740856
# 3  71.730978  220.042470
# 4  69.881796  206.349801

# %%
X=df2[['Weight']] ## we need to make sure always that our independent feature is in 2-dimension or in dataframe
type(X)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Here we can also convert our independent feature into a 2-dimensional array using Numpy

# %%
np.array(X).shape
# Out:
# (10000, 1)

# %%
np.array(df).shape
# Out:
# (10000, 3)

# %%
 X1=df2[['Weight']]

# %%
Y=df2['Height']

# %%
type(X1)

#type(Y)
# Out:
# pandas.core.frame.DataFrame

# %%
type(Y)
# Out:
# pandas.core.series.Series

# %%
np.array(X1).shape # 2-dimensional array
# Out:
# (10000, 1)

# %%
np.array(Y).shape # one dimensional array
# Out:
# (10000,)

# %%
### train test split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=42)

# %%
X_train.shape
# Out:
# (7500, 1)

# %%
y_train.shape
# Out:
# (7500,)

# %%
X_test.shape
# Out:
# (2500, 1)

# %% [markdown]
# #Standardization : The need for this is to make the values and datapoints stay as close as possible,along with that it helps to converge faster.

# %% [markdown]
# # so the library we will be using is
#
# from sklearn.preprocessing import StandardScalar

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.60863475],
#        [ 0.64561305],
#        [ 0.01295416],
#        ...,
#        [-1.48363282],
#        [ 0.20143303],
#        [ 0.32447927]])

# %% [markdown]
# #Applying Linear Regression - ML Algorithm

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
regression.fit
# Out:
# <bound method LinearRegression.fit of LinearRegression()>

# %%
regression.coef_  # this is nothing but slope, for the equation y=mx+c, m we calculated here.
# Out:
# array([29.59862269])

# %%
print("coefficient or slope :",regression.coef_)

print("Intercept:",regression.intercept_)
# Out:
# coefficient or slope : [29.59862269]
# Intercept: 161.23075926318265

# %%
# the coefficient says that, for 1 unit movement in x-axis we will be moving 29.59 units in y-axis
# And intercept means that, when our weight value is zero, then how much our height corresponds to.

# %%
## ploting the best fit line using training data.

# %%
plt.scatter(X_train,y_train)

# now we will be plotting the lines

# %%
plt.scatter(X_train[0:30],y_train[0:30])

plt.plot(X_train,regression.predict(X_train))

# %%
#now we will be doing prediction for test data

# %%
plt.scatter(X_test,y_test)

# %% [markdown]
# #Prediction of test data
#
# 1. predicted height output=intercept+coef_(weights)
#
# 2. y_pred=161.23+ 29.33(X_test)

# %%
y_pred=regression.predict(X_test)

# %%
y_pred
# Out:
# array([179.24550972, 180.3400163 , 161.61418442, ..., 117.31727114,
#        167.19289954, 170.83489876])

# %% [markdown]
# ## performance metrics we will be looking here:
#
# 1. Mean Squared Error
# 2. Mean Absolute Error
# 3. Root Mean Squared Error
# 4. R-Square
# 5. Adjusted R-Square

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mse=mean_squared_error(y_test,y_pred)

# %%
mae=mean_absolute_error(y_test,y_pred)

# %%
rmse=np.sqrt(mse)

# %%
print("mean-squared error:",mse)
print("mean absolute error:",mae)
print("root mean-squre-error:",rmse)
# Out:
# mean-squared error: 149.31479307438
# mean absolute error: 9.720990891992406
# root mean-squre-error: 12.21944323913246

# %% [markdown]
# # R-Square
#
# Formula : R**2= 1- SSr/SSt
#
# where, SSr--> sym of squares of residuals
# and SSt --> total sum of squares
# R**2 --> Coefficient of determination

# %%
from sklearn.metrics import r2_score

# %%
score=r2_score(y_test,y_pred)

print(score)
# Out:
# 0.8573532043041168

# %% [markdown]
# # Adjusted R-Square
#
# formula :
#
# adjusted R**2 = 1-[(1-R**2)*(n-1)/(n-k-1)]
# n --> no of observations / datapoints
# k --> no of predictor variables/features

# %%
1-(1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.8572960999023169

# %% [markdown]
# #OLS technique

# %%
import statsmodels.api as sm

# %%
model=sm.OLS(y_train,X_train).fit()

# %%
prediction=model.predict(X_test)
print(prediction)
# Out:
# [ 18.01475046  19.10925704   0.38342516 ... -43.91348812   5.96214028
#    9.60413949]

# %%
print(model.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Height   R-squared (uncentered):                   0.032
# Model:                            OLS   Adj. R-squared (uncentered):              0.032
# Method:                 Least Squares   F-statistic:                              251.3
# Date:                Fri, 19 Jul 2024   Prob (F-statistic):                    1.09e-55
# Time:                        08:50:56   Log-Likelihood:                         -48785.
# No. Observations:                7500   AIC:                                  9.757e+04
# Df Residuals:                    7499   BIC:                                  9.758e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Prediciton for new data

# %%
regression.predict([[72]])
# Out:
# array([2292.33159316])

# %% [markdown]
# See, here we are getting absurd value, how can someone be as tall as 2292 Cm ?, so we have to use standardization part here.

# %%
regression.predict(scaler.transform([[72]]))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([204.76138474])
